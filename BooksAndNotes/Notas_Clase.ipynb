# %% [markdown]
# # Programación 2
#
# Clase 1 - 28/10/24

# %% [markdown]
# # Clase 2 01/11/24
#
# Parciales en papel
# Quices en moodle, el 08/11/24 primer quiz capítulos 1 y 2
#
#
# ### Definir una clase:
#
# * Camelcase notación, los nombres de clases inician siempre en mayus.
#
# public class ClassName{
#     //Métodos/Funciones notación
#     public static (lo que retorna, int, string, void si no retorna nada) nombreMetodo(parámetros del método(int n1)){ //Encabezado
#     }
# }
#
# * Si no se pone el public, no lo pueden usar otras clases.
#
# //Programar Fibonacci
#
# * Primer programa que haremos tendrá solo una clase, **tiene** que tener un método main.
#
# public static void main(Argumentos raros){
#     //Normalmente al inicio o al final (El profesor lo prefiere al final)
#     //Aquí se muestran los métodos
#     System.out.println(fibonacci(5));
# }
#
# **NO OLVIDAR EL ;**
#
# //Los ejercicios son entregables * Preguntar
#
# Instalar eclipse: Opcional, puede trabajar en jdoodle, permite trabajar varias personas al mismo tiempo en el archivo.
#
# Resolvió los ejercicios.
#
# **No vamos a interactuar con el usuario**
#
# * Propiedades importantes:
#
#     - Corrección: Verificar que todo se satisface correctamente.
#     - Eficiencia: La respuesta se debe hacer **muy** rápido.
#     - Legibilidad de código: A veces es mejor delegar tareas pequeñas a otros métodos.
#
# **Siempre vamos a retornar pronto**
#
# La división en java depende de los parámetros que le dé, por ejemplo, int/int = int.

# %% [markdown]
# # Clase 3 08/11/24
#
# **Definiciones**
#
# * POO: Metodología para hacer programas (paradigma), surge after la programación estructurada, en esta los datos son independientes de las funciones, es decir, se definen las estructuras por un lado y por otro los procedimientos. En POO las clases unifican los datos y procedimientos, los datos son llamados *properties* y los métodos *behaviors*.
# Cuando se quiere hacer un programa con POO hay que mirar cuáles son las entidades que serán los objetos, por ejemplo, en un juego de póker hay que hacer los players, las cards y el mazo. Otro ejemplo sería el SIA, con muchas entidades, como profesor, estudiante, asignatura, salones, etc, si tomamos al profesor como ejemplo, debe tener los atributos, nombre, personal id, departamento, cursos enseñados y horario, y en métodos, ensñear, consultar la lista de estudiantes, calificar y subir calificaciones.
#
# Una entidad un poco más complicada es la historia académica de cada estudiante, debe decir de quién es, qué cursos ha pasado, el estatus, asignaturas perdidas y asignaturas tomadas actualmente, y debe apoder añadir cursos, registrar notas, cambiar estados e imprimir reporte.
#
# Esos son tipos definidos por el usuario/programador, clase y tipo son sinónimos.
#
# * Clases: Se puede pensar como una template/plantilla que permite construir objetos reales. Las clases tienen dos partes, los atributos y commportamientos de la entidad. Es necesario ser minimalista, agregando atributos y métodos estrictamente necesarios.
#
# * Notación UML: Permite describir los objetos de un sistema, usaremos Draw.io la aplicación para hacer el diagrama de clases, las clases se representarán por un cuadrito que lleva el nombre de la clase (Inicia en mayus siempre), y luego tiene dos partes, los atributos y los métodos, divididas por una línea. los atributos llevarán su nombre y seguido el tipo, y los métodos llevarán los atributos que necesiten y lo que retorna (Usaremos la notación Camel case).
#
# ### Principios de la POO
#
# Los principios básicos son abstracción, encapsulación, herencia y plomorfismo.
#
# * Abstracción: "Ignorar lo que no es importante", es un proceso mental en el que uno se deshace de las cosas no importantes. Proceso que involucra el reconocer y focusear en las caracterísitcas importantes de una situación u objeto, filtrando el ignorando todos los datos innecesarios. Tienen un propósito y dependen del observador.
#
# Jerarquía de clasificaciones: clasificar entidades por jerarquía optimiza el proceso de crear un programa, por ejemplo, la clase vehículo primera, luego las clases vehículo acuático, anfibio y terrestre, luego vendrían los automóviles y trenes en vehículos de terreno por ejemplo. Y si por ejemplo todos tienen un ID y dueño, estos atributos irían solo en la clase vehículo.
#
# **NOTA**: Las clases DIOS son aquellas que tienen muchos atributos.
#
# ## Implementación en Java
#
# Siempre **public class**, los atributos de la clase normalmente son privados "private" y los métodos públicos "public". Y siempre primero van los atributos de la clase, son buenas prácticas de la programación. Método constructor, siempre va primero, no devuelve nada, es público y se le meten unos parámetros, que son los que va a inicializar los valores a los atributos, lleva el mismo nombre de la clase. En la clase, las primeras líneas explican lo que modela la clase. Un ejemplo de método constructo sería:
#
# ```
# public Account(String accountNumber, String holder, double balance){
#     this.accountNumber = accountNumber;
#     this.holder = holder;
#     ths.balance = balance;
# }
# ```
#
# Para acceder a los atributos y ¿métodos? de una clase se usa "this". + el objeto. Ese inicializador es para la clase Account que tiene los atributos:
#
# ```
# public class Account{
#     private String accountBumber;
#     private String holder;
#     private double balance;
# }
# ```
#
# Un ejemplo de método sería el siguiente:
#
# ```
# public void deposit(double amount){
#     if(amount > 0){
#         balance += amount;
#     } else{
#         return "Error";
#     }
# }
# ```
#
# Siempre hay que hacer hablar las clases con una clase runner que tendrá el método main, que tendrá lo que queremos ver en la consola.
#
# ```
# public class Runner{
#     public static void main(String[] args){
#         Account acc1 = new Account(//Parámetros);
#         System.out.println("Initial account state: " + acc1);
#         acc1.deposit(1500.0);
#         System.out.println("After deposit of 1500: " + acc1.getBalance());
#         acc1.withdraw(2000);
#         System.out.println("After withdrawal of 2000 " + acc1.getBalance());
#         acc1.withdraw(6000);
#         System.out.println("Final state: " + acc1);
#     }
# }
# ```
#
# En el proyecto, lo primero que despliega el main debe ser la interfax gráfica.

# %% [markdown]
# ## Clase 4 15/11/24
#
# Proyecto Java: Conjunto de archivos que conforman una aplicación Java, está el código fuente, los archivos compilados(.class bytecode), archivos de datos, imágenes, íconos, librerías (swing para interfaz gráfica del usuario). En eclipse se genera una carpeta llamada workspace, donde se guarden todos los proyectos.
#
# Folder: En eclipse se usan 2 folders, src (source) donde van todos los archivos .java o código fuente y bin (binary) donde van los archivos compilados o .class.
#
# Paquete: En cierta medida también es un folder que solo guarda un código fuente, se organizan de acuerdo a las relaciones que haya entre las clases que están dentro.
#
# Archivo fuente: .java.
#
# **NOTA**: Cada .java corresponde a la definición de una clase.
#
# Métodos: En java todo método pertenece a una clase, procedimiento y función no tienen datos asociados, los métodos sí.
#
# Ejemplo: (int lo que devuelve) (lo usual es que sea público para que las otras funciones/clases lo vean)
#
# ```
# public static int countPositiveNums(int numOne, int numTwo, int numThree){
#     int count = 0;
#     if(numOne > 0){
#         count++;
#     } if(numTwo > 0){
#         count++;
#     } if(numThree > 0){
#         count++;
#     };
#     return count;
# }
# ```
#
# **Ejemplo proyecto**
#
# scr > paquetes > data,business,ui
#
# data: entidades representadas
# , por ejemplo en triqui, es tablero, la entidad player y finalmente, square (una casilla).
#
# business: Lógica del negocio, controlan la partida.
#
# ui (User Interface): Clases de la interfaz, tablerito, mensajes de ganó, perdió, toda la comnicación con el usuario.
#
# resources: Imágenes
#
# al final, librerías
#
#
# **Correr un programa**
#
# Supongamos que tenemos solo una clase.
#
# ```
# public class Summing{
#     public static void main(String[] args){
#         int sum=0;
#         for(String arg: args){
#             sum += Integer.parseInt(arg);
#         }
#         System.out.println("Sum of arguments" + sum);
#     }
# }
# ```
#
# Comando para compilar
#
# ```
# javac [-options] class-name [args ...]
# ```
#
# Y para ejecutar java desde cmd:
#
# ```
# java [-options] class-name [args ...]
# ```
#
# Qué ventajas tiene esto? Lo corre fuera del IDE.
#
# [-options] o son importantes.

# %% [markdown]
# ## Clase 5 18/11/24
#
# TAREA para el viernes.
#
# El quiz les fue como un culo.
#
# **Reference Variables**
#
# - Guardan la dirección a un objeto.
#
# **Abstracción**
#
# Ya lo vimos en la anterior.
#
# **Encapsulamiento**
#
# No dejar que otras clases accedan los objetos de manera directa. Esconder los atributos, definirlos con "private", los objetos deben esconder todo lo no necesario publicar, lo normal es esconderlos todos, todos private,
#
# Cada objeto tiene un lugar en la memoria en el *heap*
# Estado, valores de un atributo en un momento dado.
#
# Siempre hacer un Test para mis clases, una clase que sea test con un main probándola.
#
# * Las clases pueden tener múltiples constructores.
#
# **Métodos getters y setters**
#
# Método getter: Lo pueden usar las otras clases para consultar atributos, el getId, retorna el ID, en algunos IDE no hay que crearlos.
# Método setter: Permite cambiar el valor de un atributo pertenenciente a un objeto.
#
# Si preparamos un atributo privado, con los getters y setters se puede acceder al valor.
#
# ```
# public String getId(){
#     return id;
# }
#
#
# public void setId(String id){
#     this.id = id;
# }
# ```
#
# **Reccomendación**: Generarlos automáticamente (ahorra tiempo).
#
# **Beneficios**: Escondo los detalles internos de cómo está creada la clase.
#
# Siempre validar el ingreso en el setter:
#
# ```
# if (name == null){
#     //mostrar que paila
# } else{
#     this.loquesea = loquesea;
# }
# ```

# %% [markdown]
# ## Clase 6 25/11/24
#
# ### **Reading CSV Files**
#
# * Clases para lectura de archivos: FILE and Scanner, ambas son clases de JAVA.
#
# * Try/Catch para errores.
#
# #### CSV FILES
#
# Archivos de texto plano con los valores separados por coma ",", CSV: Coma Separated Values, pero es archivo de texto, puede ser otro separador pero por tradición se usa una coma.
# Se pueden exportar datos de excel a csv y queda cada dato dividido por coma.
#
# #### FILE
#
# Hay una diapo con la documentación de la clase FILE
#
# La usaremos solo para represntar una clase FILE, representa archivos y directorios donde están:
#
# ```
# File inFile = new File(fileName);
# File myFile = new File("data.txt");
# File myDirectory = new File("C:/temp/data.txt"); NO RECOMENDABLE
# File myRelativeFile new FIle("/usr/local/bin/data");
# ```
#
# Representa unos datos guardados en disco.
#
# #### Scanner
#
# Documentación en las diapos, es muy importante, agarra los tokens de un string, es un *tokenizador*, toma una cadena de caracteres y los separa en tokens, tokens es lo mismo que partes o pedazos interesantes de la cadena, el scanner permite a partir de la cadena completa, sacar los tokens:
#
# Input                        |  Delimiter | Tokens
#
# Richard Chaparro, Alvaro, 23 | .          | Token 0:Ruiz Chaparro Token 1: Alvaro  Token 2: 23
#
# Cuando se optienen los tokens, el primer token es todo hasta que encuentra el delimiter, el segundo es justo después del delimiter hasta encontrar la coma. Es por eso que se pueden guardar los espacios cuando no los deseamos.
#
# ##### How to use it?
#
# ```
# String input = "";
# Scanner s = new Scanner(input).useDelimiter(",");
#
# s.next().trim(): s.next me da el siguiente token, el .trim() es un método sobre cadenas que quita los espacios antes y después.
# ```
#
# * Integer representa los enteros como objetos. Por eso se usa Integer.parseInt(variable);
#
# * Float.parseFloat(variable); Hace lo mismo que el anterior, es la clase de los números reales.
#
# float e int son clases primitivas mientras que Float e Integer son clases objeto.
#
# * nextLine(): pide línea completa, GOD
#
# * useDelimiter(String pattern), cambiar el delimiter, default es el espacio.
#
#
# * Cómo scannear un archivo?
#
# File f = new File("data.txt");
#
# Scanner sc = newScanner(f);
#
# ...
#
#
# public static void main () throws IOException{ // IOExceptions arroja errores de entrada salida, por si no existe el archivo.
# }
#
# ### Exceptions:
#
# Objetos de JAVA que representan problemas que se producen en la ejecución.
#
# **Problemas típocos:**
#
# * A user has entered an invalida data.
#
# * A file that needs to be opened vannot be found
#
# * A netewotk connection has been lost in yhe middle of communication
#
# * The JVM memory
#
# #### Cómo trbajar con eso? try/catch Statement
#
# Syntax:
#
# ```
# try{
#     // lo que debe pasar si no hay error
# }
# catch(Exception e){
#     // Maneja las excepciones
# }
# ```
#
# ```
# =======================================
# File inFile = new File("data.tct");
#
# try{
#     Scanner in = new Scanner(inFile);
#     readRecords(in);
#     Scanner.clos()
# } catch (FileNotFoundException e) {  // Se ejeccuta si hay error en el try.
#     System.err.println("No existe el archivo");
#     e.printStackTrace();
# }
# ```
#
#
# Cuando se hacen errores, podemos poner:
#
# System.exit(0);
#
# Para terminar el programa.
#
# Por ejemplo:
#
# ```
# private List<CarInfo> cars;
#
# private void readRecords(Scanner sc){
#     String line;
#     While(sc.hasNextLine()){
#         String line = sc.nextLine();
#         Scanner s = new Scanner(line);
#         String brand = s.next().trim();
#         String id = s.next().trim();
#         String model = s.next().trim();
#         String lastVisit = s.next().trim();
#         this.cars.add(new CarInfo(brand,id,model,new Date(lastVisit)));
#     }
# }
# ```
#
# ### Primitive Types and Wrapper Types in Java
#
# Primitive Type: byte, short, int, long, float, double, boolean, char
#
# Wrapper Class: Byte, Short, Integer, Long, Float, Double Boolean, Character
#
# **Autoboxing**: Propiedad de Java para revolver ambas, es decir, conversión automática de tipos primitivos a obejct wrapper classes.
#
# ```
# Integer [] number = new Integer[10]
#
# for(int i=0;i<10;i++){
#     numbers[i] = i;
# }
# ```
#
# **Unboxing**: Lo contrario, conversión automática de object wrapper class a Primitive type.
#
# ```
# Integer a = new Integer(5);
# int b = a;
# ```

# %% [markdown]
# ## Clase 7 02/12/2024
#
# **Hacer la batalla naval viendo el libro - Cap 5**
#
# **Traer idea de proyecto**

# %% [markdown]
# ## Clase 9 09/11/2024
#
# ### Herencia:
#
# Es una relación entre clases, otra flechita, para decir que los objetos de la clase A también son de la clase B, "es un", "is a".
#
# Animal <- Feline, Reptile, Insect
#
# Reptile <- Snake Crocodile
#
# Herencia: Flechita con triángulo $\Delta$
#
# Snake es clase repitle y clase animal, **En herencia se da transitividad**
#
# Cómo es en java?
#
# public class Animal{
#     ...
# }
#
# public class Reptile extends Animal{
#     ...
# }
#
# public class Snake extends Animal{
#
# }
#
# **SOLO HAY UNA CLASE MADRE, LA HERENCIA ES SIMPLE, NO MÚLTIPLE**
#
# #### Beneficios:
#
# - Se pueden modelar problemas reales.
#
# - Permite ahorrar métodos y atributos.
#
#
# ### Polimorfismo
#
# Con herencia los objetos pueden tener más de un tipo, esa es la definición de polimorfismo, puede ser de dos tipos.
#
# En UML ponemos los atributos heredados con #, además de más y menos.
#
#
# **Atributo protegido: Solo lo pueden ver las clases hiajs**
#
# - Público: Class, Package, Subclass, World
#
# - Protected: Class, Package, Subclass
#
# - Nada: Class, Package
#
# - Private: Class
#
# #### Clase Object de Java
#
# Está en el API de Java, es la mamá de todas las clases, así no se especifique.
#
# Tiene varios métodos como toString que devuelve un string que identifica al objeto
#
# @Override, si quiero sobre escribir un método, pongo esta notación antes de redefinir el método en la subclase.
#
#
# #### Especialización / Generalización
#
# Especialización: Creo la madre y voy creando las hijas. (Top Down)
#
# Generalización: Tengo las clases hijas y veo que todo se puede agrupar y lo meto ahí. (Botton up)
#
# #### Ejemplo: Tienda de antigüedades, sin herencia primero

# %% [markdown]
# ## Clase 8 13/12/24
#
# EL método toString es de la clase Object, lo podemos reescribir para que al hacer print(NuestroObjeto) salga lo que queremos en lugar de hacer todo un print customizado.
#
# Código repetido:
#
# ```
# private ArrayList<Vase> vases;
# private ArrayList<Statue> statues;
# private ArrayList<Paint> paintings;
# ```
#
# Se reputen atribute value, atriute creator, getters and setters fpr value, getters amd setters for creator.
#
# Los códigos que muestran los objetos son igualitos.
#
# Rediseño con herencia.
#
# Super(): invoca la clase madre, se le pasan los atributos que la clase necesita.
#
#
# MissusingInheritance, es cuando no se usa para lo que debe ser. cuando la case es subtipo de otra.

# %% [markdown]
# ## Clase 9 16/12/24
#
# Para el regreso revisar los capítulos 8, 7 y 6. Zzz
#
# **Clases Abstractas, Interfaces y Herencia.**
#
# - Método abstracto: No tiene implementación, por ejemplo:
#
#     int compareTo(T o);
#
#     Solo existe el encabezado, le falta el cuerpo, por eso es método abstracto.
#
# - Clase abstracta: Una clase con al menos un método abstracto.
#
# **En Interfaces todos los métodos están sin cuerpo, esa es la definición**
#
# El método compareTo es un método de la interfaz Comparable<T>, sirve para comparar dos elementos del mismo tipo, devuelve un entero, se dejan sin cuerpo para que en otras clases se pueda implementar y crear. Mira si son iguales, uno mayor o menor que otro, dependiendo de la dirección que ocupa en el diccionario. 0 si son iguales < -1 si a <b y > 1 si b <a, en la cadena a.compareTo(b)>.
#
# Se construye como:
#
# ```
# public abstract class Silla{
#     ...
#     public abstract String removerDelCatalogo();
# }
# ```
# Extensión de una clase abstracta:
#
# Cuando una clase normalita extiende una clase abstracta, debe crear los métodos abstractos de las madres.
#
# ```
# public class Gerencial extends Silla{
#     public Gerencial(String ref, int precio, float calificacion){
#         super(ref,precio,calificacion);
#     }
#
#     @Override
#     public removeDelCatalogo(){
#         if (this.calificacion < 4 11 this.precio > 300000){
#             return "remove";
#         }
#         return "keep";
#     }
#
#     @Override
#     public String toString(){
#         ....
#     }
# }
# ```
#
# Es una clase normalita pero extiende una clase abstracta.
#
# Qué pasa si no lo implementa el método abstracto, debe declararse también como abstracta. Si no, sí hay un error.
#
# Qué es una Interfaz?
#
# Todos los métodos son abstractos.
#
# piblic interface Comparable<T>{
#     public int compaeTo(T o);
# }
#
#
# Ejemplo de implementación de Interface:
#
# Clase Student implementa la interface comparable.
#
# En UML se le pone <<interface>> a la interface.
#
#
# ```
# public class Student implements Comparable<Student>{
#     ...
#     public Student(String name, ...){...}
#
#     @Override
#     public String toString{...}
#
#     @Override
#     public int compareTo(Student s){
#         if(this.gpa > s.gpa){
#             return 1;
#         } else if(this.gpa < s.gpa){
#             return -1;
#         }
#         return 0;
#     }
# }
# ```
#
# **Relaciones Clases e Interfaces**
#
# - Una clase puede heredar de otra: extends.
#
# - Una clase puede implementar una interfaz: implements.
#
# - Una interfaz puede heredar una interfaz: extends
#
#
# Clases abstractas en interfaces, no pueden crear objetos, por ejemplo:
#
# Silla s = new Silla("Osaka", 350000, 4.3);
#
# Comparable c = new Comparable();
#
# Error, pues hay métodos indefinidos.

# %% [markdown]
# ## Clase 20/01/25
#
# ### Capítulo 9
#
# * Stack: Almacena los métodos llamados y las variables locales. Se almacena como pila. Siempre se apilan y mientras no contesten los otros métodos, el viejo duerme. Un ejemplo son las funciones recursivas, como el factorial, si aplicamos factorial(5), se almacenan así en el stack:
# factorial(5), factorial(4), factorial(3), factorial(2), factorial(1) = 1, 1*factorial(2), 2*factorial(3), 6*factorial(4), 24*factorial(5) = 120.
#
# * Heap: Almacena los objetos, todos los objetos creados quedan acá, cada que se hace un new.
#
# * Local Variable: Declaradas dentro de métodos, incluyendo los parámetros.
#
# * Instance Variable: Declaradas dentro de una clase pero no dentro de un método.
#
# * Método constructor: Si no creamos uno, el compilador lo hace automáticamente. Mismo nombre, no tiene retorno.
#
# * Herencia: Relación entre constructores: En la super clase hay súper atributos. Suponiendo que la super clase tiene a,b,c atributos, y la subclase snowboard x, y y z. Si definimos x = new Snowboard(), x tendrá 6 atributos. Si los constructores de una clase y una subclase, imprimen algo y se llama al constructor de la subclase, entonces se imprime primero el de la super clase y luego se imprime el de la subclase.
#
# * Super(): para llamar instrucciones de la super clase, debe ubicarse siempre de primero.
#
#
# ```
# class Person{
#     private String name
#     private int age
#
#     public Person(String name, int age){
#         this.name = name
#         this.age = age
#     }
#
#     public void displayDetails(){
#         System.out.println("Name"+ name)
#         System.out.println("Age"+ age)
#     }
# }
#
# class Student extends Person{
#     private String major
#
#     public Student(String name, int age, String major){
#         super(name, age) # El constructor de persona se encarga de estos atributos.
#         this.major = major # El atributo major lo inicializa Student.
#     }
#
#     @override
#     public void displayDetails(){
#         super.displayDetails();
#         System.out.println("Major", major)
#     }
# }
# ```
#
#
# Se pueden crear múltiples constructores con el mismo nombre pero el comportamiento lo ponemos con super().
#
# **Tener en cuenta**:
#
# 1- Los constructores se encargan de inicializar los atributos de una clase.
#
# 2- Se puede hacer múltiples constructores pero deben tener cositas distintas.
#
# 3- La palabra _this_ se usa para invocar a un constructor de la misma clase.
#
# 4- La palabra _super_ para cosas que están arriba.
#
# 5- Si no define constructor, el compilador pone uno por defecto.

# %% [markdown]
# ## Clase 27/01/25
#
# ### **Capitulo 10**
#
# **Static and final keywords**
#
# #### **Static**
#
# Hay clases static, métodos static y atributos static, el atributo static no pertenece a ningun objeto, los atributos/métodos estáticos se acceden através del nombre de la clase.
#
# public class Student{
#     private int id;
#     private static int numberOfStudents = 0;
#
#     public Student(){
#         id = ++numberOfStudents
#     }
#
#     public int getID(){
#         return id;
#     }
#
#     public static int getNumberOfStudents(){
#         return numberOfStudents;
#     }
# }
#
# #### **Final**
#
# Al aplicarlo a una variable, se vuelve una constante.
#
# Al aplicarlo a un método quiere decir que ninguna clase puede sobreescribir ese método, si es una constante, va en mayúsculas.
#
# Y en el caso de aplicarlo a clases, significa: "De esta clase no pueden haber hijas".
#
# Para definir una constante de una clase, se usa static y final.
#
#
# #### **Clases Static**
#
# Son clases que trabajaremos el viernes, como math, random, etc, las ya establecidas.

# %% [markdown]
# ## Clase 31/01/25
#
# ### **SWING:** Introduction to GUI
#
# #### Observer Pattern
#
# Define una relación orientada a objetos, hay un objeto subject y otro observer, hay una relación entre ellos.
#
# Cómo funciona?
#
# Mientras el observer esté suscrito al subject, le llegará la notificación si hay algo nuevo.
#
# - subscribe
#
# - unsubscribe
#
# Típicamente el subject es un butón, y los observers los que están detectando cambios.
#
# Métodos:
#
# **Subject**
#
# - Register(observer)
#
# - Remove(observer)
#
# - notify(observer)
#
# **Observer**
#
# - update(subject)
#
#
# Los observers se conocen también como listeners, los subjects pueden disparar un action event cuando se interactúa con él.
